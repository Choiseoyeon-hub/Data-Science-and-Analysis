# %% [markdown]
# <a href="https://colab.research.google.com/github/Choiseoyeon-hub/Data-Science-and-Analysis/blob/main/5%EC%A3%BC%EC%B0%A8_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.Pandas DataFrame**

# %%
import pandas as pd

sr = pd.Series([100, 200, 300, 400])
sr.index = ['A', 'B', 'O', 'AB']
sr
# Out:
# A     100
# B     200
# O     300
# AB    400
# dtype: int64

# %%
sr1 = pd.Series([10, 20, 30])
sr1
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
df = pd.DataFrame({'키':[170, 180, 175], '몸무게':[65, 78, 70]})
df.index = ['스파이더맨', '닥터스트레인지', '아이언맨']
df
# Out:
#            키  몸무게
# 스파이더맨    170   65
# 닥터스트레인지  180   78
# 아이언맨     175   70

# %% [markdown]
# 1)구글 드라이버에 파일 업로드

# %% [markdown]
# 2)CSV 파일 읽기

# %%
df = pd.read_csv('scores.csv', encoding='cp949')
df
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 4    scott    NaN   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60    NaN
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %% [markdown]
# 3)데이터 정보 확인

# %%
df.head()
# Out:
#        이름     국어   영어     수학
# 0    tony  100.0   90   95.0
# 1     sam   90.0   80   75.0
# 2  vision   95.0  100  100.0
# 3   peter  100.0  100  100.0
# 4   scott    NaN   35   60.0

# %%
df.tail()
# Out:
#         이름     국어   영어    수학
# 5      tor   70.0   75  65.0
# 6    bruce   80.0   90  55.0
# 7     thor   50.0   60   NaN
# 8  steaven  100.0  100  90.0
# 9    wanda   90.0   95  70.0

# %%
df.sample(3)
# Out:
#         이름     국어   영어    수학
# 9    wanda   90.0   95  70.0
# 8  steaven  100.0  100  90.0
# 5      tor   70.0   75  65.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      10 non-null     object
#  1   국어      9 non-null      float64
#  2   영어      10 non-null     int64
#  3   수학      9 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 448.0+ bytes

# %%
df.shape
# Out:
# (10, 4)

# %%
len(df)
# Out:
# 10

# %% [markdown]
# 4)결측값 분석 및 처리

# %%
df.isnull().sum()
# Out:
# 이름    0
# 국어    1
# 영어    0
# 수학    1
# dtype: int64

# %%
df_dropna = df.dropna()
df_dropna
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
df_fillna = df.fillna(50)
df_fillna
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 4    scott   50.0   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60   50.0
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %% [markdown]
# 5)통계 정보 확인

# %%
df.describe()
# Out:
#                국어          영어          수학
# count    9.000000   10.000000    9.000000
# mean    86.111111   82.500000   78.888889
# std     16.914819   21.114766   17.638342
# min     50.000000   35.000000   55.000000
# 25%     80.000000   76.250000   65.000000
# 50%     90.000000   90.000000   75.000000
# 75%    100.000000   98.750000   95.000000
# max    100.000000  100.000000  100.000000

# %%
df['국어'].sum()
# Out:
# 775.0

# %%
df.value_counts('영어')
# Out:
# 영어
# 100    3
# 90     2
# 35     1
# 60     1
# 75     1
# 80     1
# 95     1
# dtype: int64

# %% [markdown]
# 6)데이터 추출 - 인덱스와 컬럼명으로 추출

# %%
df['국어']
# Out:
# 0    100.0
# 1     90.0
# 2     95.0
# 3    100.0
# 4      NaN
# 5     70.0
# 6     80.0
# 7     50.0
# 8    100.0
# 9     90.0
# Name: 국어, dtype: float64

# %%
df[['국어', '영어']]
# Out:
#       국어   영어
# 0  100.0   90
# 1   90.0   80
# 2   95.0  100
# 3  100.0  100
# 4    NaN   35
# 5   70.0   75
# 6   80.0   90
# 7   50.0   60
# 8  100.0  100
# 9   90.0   95

# %%
df.loc[1]
# Out:
# 이름     sam
# 국어    90.0
# 영어      80
# 수학    75.0
# Name: 1, dtype: object

# %%
df.loc[[1,2,3]]
# Out:
#        이름     국어   영어     수학
# 1     sam   90.0   80   75.0
# 2  vision   95.0  100  100.0
# 3   peter  100.0  100  100.0

# %% [markdown]
# 7)데이터 추출 - 행시퀀스와 열시퀀스로 추출

# %%
df.iloc[2]
# Out:
# 이름    vision
# 국어      95.0
# 영어       100
# 수학     100.0
# Name: 2, dtype: object

# %%
df.iloc[2:5]
# Out:
#        이름     국어   영어     수학
# 2  vision   95.0  100  100.0
# 3   peter  100.0  100  100.0
# 4   scott    NaN   35   60.0

# %%
# 시퀀스가 아니라 인덱스로 추출
df.loc[2:5]
# Out:
#        이름     국어   영어     수학
# 2  vision   95.0  100  100.0
# 3   peter  100.0  100  100.0
# 4   scott    NaN   35   60.0
# 5     tor   70.0   75   65.0

# %%
df
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 4    scott    NaN   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60    NaN
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
df.iloc[1,3]
# Out:
# 75.0

# %%
df.iloc[1:3, 1:3]
# Out:
#      국어   영어
# 1  90.0   80
# 2  95.0  100
